# %% [markdown]
# <a href="https://colab.research.google.com/github/cuhkrsdi/newspaper-analytics/blob/main/data_preprocessing_and_NLP_(Public).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import os
import pandas as pd
from urllib.request import urlopen

# %%
def path_to_df(filepath_list):
    counter = 0
    whole_df = pd.DataFrame(columns=["filename", "content", "newspaper", "year", "month_day"])
    whole_df = whole_df.astype(str)
  
    # modified for URL demo
    for url in filepath_list:
        txt_lines = list()
        file = urlopen(url)
        for line in file:
            decoded_line = line.decode("utf-8")
            txt_lines.append(decoded_line)
           
        # edit the list of lines into a long string with no \n \r
        join_str = ''.join(txt_lines)
        content = join_str.replace("\r", "").replace("\n", "")
        
        # modified for URL demo
        without_file_extension = os.path.splitext(url)[0]  
        filename = without_file_extension.rsplit('/', 1)[-1]
        
        newspaper = filename[: filename.find("19")]
        year = filename[filename.find("19") : filename.find("19") + 4]
        month_day = filename[filename.find("19") + 4 : filename.find("19") + 8]
        row = [filename, content, newspaper, year, month_day]
    
        # append list to df as row 
        whole_df.loc[len(whole_df)] = row
        print("--- %s seconds ---" % (time.time() - start_time))
        print(counter)
        counter += 1
    
    return whole_df

# %%
# Ignore SSL for url demo
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# run 
start_time = time.time()
filepath_list = ['https://dsprojects.lib.cuhk.edu.hk/media/filer_public/e6/01/e6010cbc-1d9f-48e0-b6d3-f164cae4450a/observatoryreview19690102_001.txt',
         'https://dsprojects.lib.cuhk.edu.hk/media/filer_public/d1/bd/d1bd9458-988c-4a64-a4f5-1dee826ff6f9/observatoryreview19690102_002.txt',
         
         'https://dsprojects.lib.cuhk.edu.hk/media/filer_public/93/41/93417356-9631-4edb-b184-3aedc4130e16/observatoryreview19690104_001.txt',
         'https://dsprojects.lib.cuhk.edu.hk/media/filer_public/c2/c4/c2c4c55c-d65f-4a58-8292-434a3ad6e2ed/observatoryreview19690104_002.txt',
        ]
df = path_to_df(filepath_list)
# Out:
# --- 1.1334254741668701 seconds ---
# 0
# --- 2.238529920578003 seconds ---
# 1
# --- 3.1338400840759277 seconds ---
# 2
# --- 4.252142906188965 seconds ---
# 3

# %%
df
# Out:
#                         filename  \
# 0  observatoryreview19690102_001
# 1  observatoryreview19690102_002
# 2  observatoryreview19690104_001
# 3  observatoryreview19690104_002
#
#                                              content          newspaper  year  \
# 0  ﻿天文臺中華民圃內政部內荫澄R，扳瑟台鼹真L藉））1  ）虎辱藝民圈僑務委員岔登記證台敌新事...  observatoryreview  1969
# 1  ﻿職業與壽命圃·司馬我·美圃累辦的一顷有趣的統計資料指出，事業上有所成就的人，往宝七一发人舌...  observatoryreview  1969
# 2  ﻿天文臺中中華嚣民民圈圃僑內務政委部員內窗銷登證耙內誼版台儘教台新辍字字藷篛  O  O六一...  observatoryreview  1969
# 3  ﻿英中璧合「太平洋鼓吹集」陳孝咸编著"L.\UDS ACROSS THE PACIFIC"定...  observatoryreview  1969
#
#   month_day
# 0      0102
# 1      0102
# 2      0104
# 3      0104

# %% [markdown]
# Install CKIP Transformer package

# %%
import pandas as pd
# !pip install -U transformers 
# !pip install -U ckip-transformers
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 5.2 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 44.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 10.6 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 51.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.20.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ckip-transformers
#   Downloading ckip_transformers-0.2.8-py3-none-any.whl (26 kB)
# Requirement already satisfied: transformers>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ckip-transformers) (4.20.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from ckip-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from ckip-transformers) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->ckip-transformers) (4.1.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (4.11.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (3.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (1.21.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.5.0->ckip-transformers) (0.12.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=3.5.0->ckip-transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=3.5.0->ckip-transformers) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.5.0->ckip-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.5.0->ckip-transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.5.0->ckip-transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.5.0->ckip-transformers) (1.24.3)
# Installing collected packages: ckip-transformers
# Successfully installed ckip-transformers-0.2.8

# %% [markdown]
# Read Json of Raw text dataframe to run NLP, 1969-1972

# %%
# choose how many rows of content to process
# selected_rows = 3

sum_df = pd.DataFrame()
for fileorder in range(0, len(df)): 
  lst_261 = df['content'][fileorder:fileorder + 1].to_list()

  ner_driver = CkipNerChunker(level=3, device=-1)
  ner = ner_driver(lst_261, use_delim=True)
  ner_df = pd.DataFrame.from_records(ner)

  # remove Null cells
  pm = ner_df.apply(sorted,key=pd.isnull)
  new = pm[~pd.isnull(pm).all(1)].fillna('')
  new 

  print(new)
  sum_df = sum_df.append(new)
  print(f"Progressed: {fileorder}")

reset_df = sum_df.reset_index(drop=True)   # .sort_index().reset_index(drop=True)
  # Save the DataFrame to a file on the Colab backend.
#with open('/content/drive/MyDrive/Colab Notebooks/RawDfwithFilename/Lasttest001.json', 'w') as f:
  #f.write(reset_df.to_json())




"""
  # Download the file.
  from google.colab import files
  files.download('df.json')
"""
# Out:
# Downloading:   0%|          | 0.00/3.62k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/388M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Tokenization: 100%|██████████| 1/1 [00:00<00:00, 90.62it/s]
# Inference: 100%|██████████| 2/2 [01:37<00:00, 48.79s/it]
#                           0                           1    \
# 0  (天文臺中華民圃內政部, ORG, (1, 11))  (4壹幣港份, MONEY, (186, 191))
#
#                       2                        3                          4    \
# 0  (下月, DATE, (196, 198))  (毛, PERSON, (198, 199))  (華沙會談, EVENT, (200, 204))
#
#                          5                          6    \
# 0  (張六師, PERSON, (208, 211))  (一, CARDINAL, (293, 294))
#
#                         7                         8    \
# 0  (克遜, PERSON, (297, 299))  (二一月月, DATE, (317, 321))
#
#                         9    ...                          191  \
# 0  (十十日六, DATE, (323, 327))  ...  (梅來丫, PERSON, (3777, 3780))
#
#                        192                       193  \
# 0  (寶際, ORG, (3810, 3812))  (以色列, GPE, (3836, 3839))
#
#                         194                     195                     196  \
# 0  (以色列, GPE, (3857, 3860))  (以, GPE, (3899, 3900))  (阿, GPE, (3900, 3901))
#
#                          197                         198  \
# 0  (郝, PERSON, (3909, 3910))  (阿刺伯集團, ORG, (3918, 3923))
#
#                         199                          200
# 0  (以色列, GPE, (3958, 3961))  (碉穎捌, PERSON, (3965, 3968))
#
# [1 rows x 201 columns]
# Progressed: 0
# Tokenization: 100%|██████████| 1/1 [00:00<00:00, 73.87it/s]
# Inference: 100%|██████████| 2/2 [01:43<00:00, 51.91s/it]
#                            0                         1    \
# 0  (紐約人壽保險公司, ORG, (112, 120))  (昆特, PERSON, (125, 127))
#
#                         2                           3    \
# 0  (柯鸞, PERSON, (128, 130))  (二人, QUANTITY, (130, 132))
#
#                          4                            5    \
# 0  (美圃公司協會, ORG, (134, 140))  (一九五五至五六, DATE, (158, 165))
#
#                                 6                                7    \
# 0  (美國人物誌, WORK_OF_ART, (169, 174))  (六千三百二十九, CARDINAL, (179, 186))
#
#                       8                           9    ...  \
# 0  (十年, DATE, (210, 212))  (四十, CARDINAL, (275, 277))  ...
#
#                              220                           221  \
# 0  (六十號, CARDINAL, (5997, 6000))  (60, CARDINAL, (6035, 6037))
#
#                              222                      223  \
# 0  ( Road, PERSON, (6047, 6052))  (福建, GPE, (6076, 6078))
#
#                            224                         225  \
# 0  (第三, ORDINAL, (6080, 6082))  (一月十日, DATE, (6092, 6096))
#
#                              226                        227  \
# 0  (新台幣壹拾元, MONEY, (6098, 6104))  (台北郵局, ORG, (6108, 6112))
#
#                            228                           229
# 0  (第三, ORDINAL, (6112, 6114))  (二十, CARDINAL, (6154, 6156))
#
# [1 rows x 230 columns]
# Progressed: 1
# Tokenization: 100%|██████████| 1/1 [00:00<00:00, 105.34it/s]
# Inference: 100%|██████████| 2/2 [03:03<00:00, 91.70s/it]
#                           0                         1    \
# 0  (毫壹幣港伦, MONEY, (162, 167))  (毛澤東羅織, ORG, (170, 175))
#
#                          2                          3    \
# 0  (劉少奇, PERSON, (178, 181))  (毛澤東, PERSON, (201, 204))
#
#                         4                          5    \
# 0  (林彪, PERSON, (206, 208))  (文化革命, EVENT, (213, 217))
#
#                          6                             7    \
# 0  (劉少奇, PERSON, (257, 260))  (中勖赫魯曉夫, PERSON, (282, 288))
#
#                           8                             9    ...  \
# 0  (蘇修走狗, PERSON, (291, 295))  (八縛擴大十二中金會, ORG, (317, 326))  ...
#
#                            148                            149  \
# 0  (唐淵琛, PERSON, (3444, 3447))  (七十六, CARDINAL, (3796, 3799))
#
#                          150                          151  \
# 0  (    , ORG, (3803, 3807))  (港幣五元, MONEY, (3812, 3816))
#
#                             152                        153  \
# 0  (香港天文台報社, ORG, (3833, 3840))  (香港禮頓, GPE, (3852, 3856))
#
#                            154                       155  \
# 0  (七, CARDINAL, (3860, 3861))  (台北市, GPE, (3880, 3883))
#
#                          156                           157
# 0  (長安東路, LOC, (3883, 3887))  (十虢, CARDINAL, (3889, 3891))
#
# [1 rows x 158 columns]
# Progressed: 2
# Tokenization: 100%|██████████| 1/1 [00:00<00:00, 78.86it/s]
# Inference: 100%|██████████| 2/2 [01:55<00:00, 57.72s/it]
#                       0                        1                        2    \
# 0  (太平洋鼓吹集, ORG, (6, 12))  (陳孝咸, PERSON, (13, 16))  (8, CARDINAL, (66, 67))
#
#                           3                            4    \
# 0  (二十, CARDINAL, (138, 140))  (1L——, PRODUCT, (148, 152))
#
#                          5                           6    \
# 0  (瀚亿麗, PERSON, (200, 203))  (缀基曼蚕, PERSON, (301, 305))
#
#                      7                         8                         9    \
# 0  (美國, GPE, (314, 316))  (詹森, PERSON, (318, 320))  (邱仕, PERSON, (340, 342))
#
#    ...                         226                         227  \
# 0  ...  (毛酋, PERSON, (5253, 5255))  (毛奮, PERSON, (5341, 5343))
#
#                             228                         229  \
# 0  (ii  , PERSON, (5398, 5402))  (毛酋, PERSON, (5440, 5442))
#
#                           230                          231  \
# 0  (鶯齡, PERSON, (5490, 5492))  (毛旨心, PERSON, (5525, 5528))
#
#                           232                      233  \
# 0  (毛酋, PERSON, (5560, 5562))  (福建, GPE, (5619, 5621))
#
#                            234                              235
# 0  (十1月十日, DATE, (5631, 5636))  (新台幣壹拾元一一, MONEY, (5651, 5659))
#
# [1 rows x 236 columns]
# Progressed: 3
# "\n  # Download the file.\n  from google.colab import files\n  files.download('df.json')\n"

# %%
reset_df
# Out:
#                            0                           1    \
# 0   (天文臺中華民圃內政部, ORG, (1, 11))  (4壹幣港份, MONEY, (186, 191))
# 1  (紐約人壽保險公司, ORG, (112, 120))    (昆特, PERSON, (125, 127))
# 2   (毫壹幣港伦, MONEY, (162, 167))    (毛澤東羅織, ORG, (170, 175))
# 3       (太平洋鼓吹集, ORG, (6, 12))     (陳孝咸, PERSON, (13, 16))
#
#                          2                           3    \
# 0     (下月, DATE, (196, 198))     (毛, PERSON, (198, 199))
# 1   (柯鸞, PERSON, (128, 130))  (二人, QUANTITY, (130, 132))
# 2  (劉少奇, PERSON, (178, 181))   (毛澤東, PERSON, (201, 204))
# 3    (8, CARDINAL, (66, 67))  (二十, CARDINAL, (138, 140))
#
#                            4                            5    \
# 0    (華沙會談, EVENT, (200, 204))    (張六師, PERSON, (208, 211))
# 1    (美圃公司協會, ORG, (134, 140))  (一九五五至五六, DATE, (158, 165))
# 2     (林彪, PERSON, (206, 208))    (文化革命, EVENT, (213, 217))
# 3  (1L——, PRODUCT, (148, 152))    (瀚亿麗, PERSON, (200, 203))
#
#                                 6                                7    \
# 0         (一, CARDINAL, (293, 294))         (克遜, PERSON, (297, 299))
# 1  (美國人物誌, WORK_OF_ART, (169, 174))  (六千三百二十九, CARDINAL, (179, 186))
# 2         (劉少奇, PERSON, (257, 260))     (中勖赫魯曉夫, PERSON, (282, 288))
# 3        (缀基曼蚕, PERSON, (301, 305))            (美國, GPE, (314, 316))
#
#                           8                             9    ...  \
# 0    (二一月月, DATE, (317, 321))      (十十日六, DATE, (323, 327))  ...
# 1      (十年, DATE, (210, 212))    (四十, CARDINAL, (275, 277))  ...
# 2  (蘇修走狗, PERSON, (291, 295))  (八縛擴大十二中金會, ORG, (317, 326))  ...
# 3    (詹森, PERSON, (318, 320))      (邱仕, PERSON, (340, 342))  ...
#
#                              226                         227  \
# 0                            NaN                         NaN
# 1  (新台幣壹拾元, MONEY, (6098, 6104))   (台北郵局, ORG, (6108, 6112))
# 2                            NaN                         NaN
# 3     (毛酋, PERSON, (5253, 5255))  (毛奮, PERSON, (5341, 5343))
#
#                             228                           229  \
# 0                           NaN                           NaN
# 1   (第三, ORDINAL, (6112, 6114))  (二十, CARDINAL, (6154, 6156))
# 2                           NaN                           NaN
# 3  (ii  , PERSON, (5398, 5402))    (毛酋, PERSON, (5440, 5442))
#
#                           230                          231  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3  (鶯齡, PERSON, (5490, 5492))  (毛旨心, PERSON, (5525, 5528))
#
#                           232                      233  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3  (毛酋, PERSON, (5560, 5562))  (福建, GPE, (5619, 5621))
#
#                            234                              235
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3  (十1月十日, DATE, (5631, 5636))  (新台幣壹拾元一一, MONEY, (5651, 5659))
#
# [4 rows x 236 columns]

# %% [markdown]
# All column of filename back to result

# %%
# selected_filename_list = df['filename'].tolist() # [0:selected_rows]

ymd_filename_list = [name[name.find("19") : name.find("19") + 8] for name in df['filename']]

# %%
# length check
if all(len(ymd) == 8 for ymd in ymd_filename_list): 
  print('Valid') 
else: 
  print('Potential ERROR')
# Out:
# Valid

# %%
ymd_filename_list
# Out:
# ['19690102', '19690102', '19690104', '19690104']

# %% [markdown]
# NLP result dataframe to nested dictionary

# %% [markdown]
# Rearrange token to nested dictionary
# ymd_frequency = {ymd: {word: {type1: freq, type2:freq, ...}}}

# %%
# modified for demo 
ymd_frequency_dict = dict()
for rowIndex, row in reset_df.iterrows():
  # set filename from dropped list as variable as key
  ymd_key = ymd_filename_list[rowIndex]
  print(f"Progress: {rowIndex}")
  for columnIndex, value in row.items():
    try:
    #if isinstance(value, list):
      ner_word = value.word  # value[0]
      ner_type = value.ner  # value[1]
      #
      if ymd_key not in ymd_frequency_dict:
        #
        ymd_frequency_dict[ymd_key] = dict()
      #
      if ner_word not in ymd_frequency_dict[ymd_key]:
        #
        ymd_frequency_dict[ymd_key][ner_word] = dict()
      # 
      if ner_type not in ymd_frequency_dict[ymd_key][ner_word]:
        ymd_frequency_dict[ymd_key][ner_word][ner_type] = ymd_frequency_dict[ymd_key][ner_word].get(ner_type, 1)
      else:
        ymd_frequency_dict[ymd_key][ner_word][ner_type] = ymd_frequency_dict[ymd_key][ner_word].get(ner_type, 1) + 1
    except (TypeError, AttributeError):
      continue
# Out:
# Progress: 0
# Progress: 1
# Progress: 2
# Progress: 3

# %%
ymd_frequency_dict
# Out:
# {'19690102': {'  ': {'ORG': 1, 'PERSON': 1},
#   '    ': {'ORG': 6, 'PERSON': 3, 'PRODUCT': 1},
#   '    伊': {'FAC': 1},
#   '  人': {'NORP': 1},
#   ' Road': {'PERSON': 1},
#   '1年': {'DATE': 3},
#   '4壹幣港份': {'MONEY': 1},
#   '60': {'CARDINAL': 1},
#   '62': {'CARDINAL': 1},
#   "d'7": {'PERSON': 1},
#   'rd': {'PERSON': 1},
#   '一': {'CARDINAL': 8},
#   '一九五五年': {'DATE': 1},
#   '一九五五至五六': {'DATE': 1},
#   '一九六二年': {'DATE': 1},
#   '一九六二年七月1日': {'DATE': 1},
#   '一年': {'DATE': 3},
#   '一月十日': {'DATE': 1},
#   '一百八十何以上': {'CARDINAL': 1},
#   '一週前': {'DATE': 1},
#   '七億': {'CARDINAL': 1},
#   '三': {'CARDINAL': 5},
#   '三十年後': {'DATE': 1},
#   '上海': {'GPE': 1},
#   '上週': {'DATE': 3},
#   '下午': {'TIME': 2},
#   '下月': {'DATE': 1},
#   '世拉': {'PERSON': 1},
#   '世界革命': {'EVENT': 1},
#   '丙韶': {'PERSON': 1},
#   '中': {'GPE': 1},
#   '中共': {'ORG': 3},
#   '中國': {'GPE': 1, 'NORP': 1},
#   '中國人': {'NORP': 1},
#   '中國軍': {'ORG': 1},
#   '中央': {'ORG': 1},
#   '中央政治局': {'ORG': 1},
#   '中央黨校': {'ORG': 1},
#   '中東': {'LOC': 2},
#   '中東航空公司': {'ORG': 1},
#   '中東集團': {'ORG': 1},
#   '中棗的珍珠港事件': {'EVENT': 1},
#   '中箋民國五十八': {'DATE': 1},
#   '中美防衛協定': {'LAW': 1},
#   '中華': {'NORP': 2},
#   '中華民國': {'GPE': 4},
#   '中驀民國': {'GPE': 1},
#   '丽内': {'GPE': 1},
#   '之一': {'CARDINAL': 1},
#   '九犬': {'EVENT': 1},
#   '二': {'CARDINAL': 1},
#   '二±炳南': {'PERSON': 1},
#   '二一月月': {'DATE': 1},
#   '二人': {'QUANTITY': 1},
#   '二十': {'CARDINAL': 2},
#   '二十多年': {'DATE': 1},
#   '二十幾': {'CARDINAL': 1},
#   '二頃': {'QUANTITY': 1},
#   '五五年': {'DATE': 1},
#   '五十九歲': {'DATE': 1},
#   '五十八年': {'DATE': 1},
#   '五十幾': {'DATE': 1},
#   '五十歲': {'DATE': 1},
#   '亞洲': {'LOC': 1},
#   '人民日釅': {'ORG': 1},
#   '今天': {'DATE': 3},
#   '今年三月廿九日': {'DATE': 1},
#   '今日': {'DATE': 2},
#   '今日昆': {'PERSON': 1},
#   '以': {'GPE': 1},
#   '以色列': {'GPE': 9},
#   '低約酉分之二十二': {'PERCENT': 1},
#   '低酉分之十': {'PERCENT': 1},
#   '何濟公': {'PERSON': 1},
#   '俄': {'GPE': 1},
#   '俄共': {'ORG': 1},
#   '倫敦': {'GPE': 1},
#   '偽王朝': {'DATE': 1},
#   '元旦': {'DATE': 2},
#   '克遜': {'PERSON': 1},
#   '兩': {'CARDINAL': 7},
#   '八十': {'CARDINAL': 1},
#   '八屆十二中全會': {'EVENT': 1},
#   '六七十萬': {'CARDINAL': 1},
#   '六十號': {'CARDINAL': 1},
#   '六千三百二十九': {'CARDINAL': 1},
#   '六年': {'DATE': 1},
#   '六年前': {'DATE': 1},
#   '共黨': {'ORG': 9},
#   '凡懿': {'PERSON': 1},
#   '前幾天': {'DATE': 1},
#   '劉少奇': {'PERSON': 1},
#   '劉行勘': {'PERSON': 1},
#   '劉道平': {'PERSON': 1},
#   '加疆': {'GPE': 1},
#   '北京外交部長': {'ORG': 1},
#   '北平': {'GPE': 1},
#   '北越': {'GPE': 1},
#   '十': {'CARDINAL': 1},
#   '十1月': {'DATE': 1},
#   '十三': {'CARDINAL': 1},
#   '十十日六': {'DATE': 1},
#   '十年': {'DATE': 3},
#   '十年前': {'DATE': 2},
#   '卡勃特': {'PERSON': 2},
#   '卡玉爾人': {'NORP': 1},
#   '印尼': {'GPE': 1},
#   '厦县': {'GPE': 1},
#   '去年九月': {'DATE': 1},
#   '反共': {'NORP': 1, 'ORG': 5},
#   '台北': {'GPE': 1},
#   '台北市': {'GPE': 1},
#   '台北郵局': {'ORG': 1},
#   '台灣': {'GPE': 1},
#   '台灣海峡': {'LOC': 1},
#   '台醫': {'NORP': 1},
#   '合峽': {'LOC': 1},
#   '同濤': {'PERSON': 1},
#   '周恩察': {'PERSON': 1},
#   '嘉一': {'GPE': 1},
#   '嚎鮰': {'GPE': 1},
#   '四十': {'CARDINAL': 1},
#   '四十幾趣': {'CARDINAL': 1},
#   '國諾片': {'ORG': 1},
#   '土': {'GPE': 1},
#   '地下革命委員會': {'ORG': 1},
#   '基黨': {'ORG': 1},
#   '大陸': {'GPE': 2, 'NORP': 1},
#   '天文台': {'ORG': 1},
#   '天文臺中華民圃內政部': {'ORG': 1},
#   '天津': {'GPE': 1},
#   '安理會': {'ORG': 1},
#   '寶際': {'ORG': 1},
#   '尖沙咀寶通銀行': {'FAC': 1},
#   '尤善怜': {'PERSON': 1},
#   '巴黎': {'GPE': 1},
#   '希臘': {'GPE': 1},
#   '年來': {'DATE': 1},
#   '延安': {'GPE': 1},
#   '廿七日下午五時卅分': {'TIME': 1},
#   '張之龍': {'PERSON': 1},
#   '張六師': {'PERSON': 1},
#   '快廿年': {'DATE': 1},
#   '文化大革命': {'EVENT': 2},
#   '文化戰': {'EVENT': 1},
#   '文革': {'EVENT': 1},
#   '新不平等條約': {'LAW': 1},
#   '新台幣壹拾元': {'MONEY': 1},
#   '新年': {'DATE': 1},
#   '於和': {'PERSON': 1},
#   '早一天': {'DATE': 1},
#   '昆特': {'PERSON': 1},
#   '明明基因中器民國政府': {'ORG': 1},
#   '星期六': {'DATE': 1},
#   '暇貞': {'PERSON': 1},
#   '杜勒斯': {'GPE': 1},
#   '杜岔組織': {'ORG': 1},
#   '杜舷斯': {'PERSON': 1},
#   '東南': {'LOC': 1},
#   '東沒西人': {'NORP': 1},
#   '柯鸞': {'PERSON': 1},
#   '柳帝': {'PERSON': 1},
#   '梅來丫': {'PERSON': 1},
#   '棗憨': {'PERSON': 1},
#   '樂帝': {'PERSON': 1},
#   '樂蒂': {'PERSON': 4},
#   '檬剁精': {'PERSON': 1},
#   '歙代': {'GPE': 1},
#   '武漢': {'GPE': 1},
#   '毛': {'GPE': 1, 'NORP': 1, 'ORG': 1, 'PERSON': 11},
#   '毛共': {'ORG': 23},
#   '毛共會': {'ORG': 1},
#   '毛岐': {'PERSON': 1},
#   '毛斡': {'PERSON': 1},
#   '毛澤東': {'PERSON': 2},
#   '毛澤棗': {'PERSON': 1},
#   '毛聶': {'PERSON': 1},
#   '毛舜': {'PERSON': 1},
#   '毛裔霄': {'PERSON': 1},
#   '毛西': {'PERSON': 1},
#   '毛記舜': {'PERSON': 1},
#   '毛酉': {'PERSON': 1},
#   '毛酋': {'PERSON': 1},
#   '毛霞': {'PERSON': 1},
#   '民國': {'GPE': 1},
#   '汀得': {'GPE': 1},
#   '河南': {'GPE': 1},
#   '法': {'GPE': 1},
#   '法疆': {'GPE': 1},
#   '波蘭': {'GPE': 2},
#   '渠': {'PERSON': 1},
#   '渭桑': {'PERSON': 1},
#   '湖南': {'GPE': 1},
#   '滿月': {'DATE': 1},
#   '潞去': {'GPE': 1},
#   '澳門': {'GPE': 1},
#   '無國族': {'NORP': 1},
#   '犬部郡': {'GPE': 1},
#   '王炳南': {'PERSON': 2},
#   '當天上午': {'TIME': 1},
#   '百分三十八': {'PERCENT': 1},
#   '百分之三十': {'PERCENT': 2},
#   '百分之二十一': {'PERCENT': 1},
#   '百分之二十九': {'PERCENT': 1},
#   '百分之十': {'PERCENT': 2},
#   '百分之十三': {'PERCENT': 1},
#   '盱街': {'FAC': 1},
#   '碉穎捌': {'PERSON': 1},
#   '福建': {'GPE': 1},
#   '禹共': {'ORG': 1},
#   '窗州': {'GPE': 1},
#   '第一': {'ORDINAL': 3},
#   '第七': {'ORDINAL': 1},
#   '第三': {'ORDINAL': 2},
#   '紐約人壽保險公司': {'ORG': 1},
#   '緒台': {'PERSON': 1},
#   '纂盛頓': {'GPE': 1},
#   '美': {'GPE': 8},
#   '美圃公司協會': {'ORG': 1},
#   '美國': {'GPE': 12, 'NORP': 2},
#   '美國人物誌': {'WORK_OF_ART': 1},
#   '美國縣': {'GPE': 1},
#   '美帝': {'PERSON': 1},
#   '美毛華沙會議': {'EVENT': 1},
#   '美洲': {'GPE': 1},
#   '美霹': {'ORG': 1},
#   '羣魔酉態錄': {'WORK_OF_ART': 1},
#   '聯合國軍': {'ORG': 1},
#   '聯合网': {'ORG': 1},
#   '脩女燃魂': {'WORK_OF_ART': 1},
#   '臻霞': {'PERSON': 1},
#   '艾思奇': {'PERSON': 1},
#   '艾雖恩奇': {'PERSON': 1},
#   '英': {'GPE': 1},
#   '英國': {'GPE': 1},
#   '英文': {'LANGUAGE': 1},
#   '英語': {'LANGUAGE': 1},
#   '華沙': {'GPE': 1},
#   '華沙會談': {'EVENT': 1},
#   '華沙美聯社': {'ORG': 1},
#   '葵靂': {'PERSON': 1},
#   '蔡加以': {'PERSON': 1},
#   '蔣': {'PERSON': 2},
#   '蔣霞': {'PERSON': 1},
#   '蔷嚣寨': {'LOC': 1},
#   '蘇俄': {'GPE': 1},
#   '蘇聯': {'GPE': 2},
#   '蘭民懿': {'PERSON': 1},
#   '詹森': {'PERSON': 1},
#   '貝魯特': {'GPE': 1},
#   '赫熊': {'PERSON': 1},
#   '越': {'GPE': 1},
#   '越共': {'ORG': 1},
#   '越南': {'GPE': 2},
#   '越國': {'GPE': 1},
#   '連渠': {'PERSON': 1},
#   '週一': {'DATE': 1},
#   '遼抵醫院': {'ORG': 1},
#   '邐': {'GPE': 1},
#   '郅韓爾': {'PERSON': 1},
#   '郝': {'PERSON': 1},
#   '郝牌靈': {'PERSON': 1},
#   '鄗蔭': {'PERSON': 1},
#   '鄭樊': {'PERSON': 1},
#   '酉分之二十五': {'PERCENT': 1},
#   '闵駕': {'PERSON': 1},
#   '阮高麒': {'PERSON': 2},
#   '阿': {'GPE': 1},
#   '阿刺伯': {'PERSON': 1},
#   '阿刺伯集團': {'ORG': 2},
#   '阿割伯': {'NORP': 1},
#   '陳伯港': {'PERSON': 1},
#   '陳伯達': {'PERSON': 1},
#   '陳孝威': {'PERSON': 1},
#   '陳毅': {'PERSON': 1},
#   '陳靜': {'PERSON': 1},
#   '陵平': {'GPE': 1},
#   '際爾頓': {'PERSON': 1},
#   '霞': {'PERSON': 1},
#   '非渠': {'PERSON': 1},
#   '革命委員會': {'ORG': 1},
#   '韓': {'PERSON': 1},
#   '韓國': {'NORP': 1},
#   '高麒': {'PERSON': 1},
#   '鬱無芬': {'PERSON': 1}},
#  '19690104': {'  ': {'PERSON': 2},
#   '    ': {'ORG': 12, 'PERSON': 2, 'PRODUCT': 2},
#   '    ④': {'ORG': 2},
#   '    日': {'DATE': 1},
#   '11…‘': {'FAC': 1},
#   '1L——': {'PRODUCT': 1},
#   '5': {'CARDINAL': 1},
#   '8': {'CARDINAL': 1},
#   'h6…{一': {'PERSON': 1},
#   'h”kpilill': {'WORK_OF_ART': 1},
#   'ii  ': {'PERSON': 1},
#   '一': {'CARDINAL': 7},
#   '一1': {'CARDINAL': 1},
#   '一九110年代': {'DATE': 1},
#   '一九二七年': {'DATE': 1},
#   '一九二五年': {'DATE': 1},
#   '一九五九至一九六一年': {'DATE': 1},
#   '一九五八年': {'DATE': 1},
#   '一九八O年': {'DATE': 1},
#   '一九八O年代': {'DATE': 1},
#   '一九六八年八月': {'DATE': 1},
#   '一兩年': {'DATE': 1},
#   '一千年前': {'DATE': 1},
#   '一奇': {'PERSON': 1},
#   '一月二日夜': {'DATE': 1},
#   '一百': {'CARDINAL': 1},
#   '七': {'CARDINAL': 1},
#   '七十六': {'CARDINAL': 1},
#   '三': {'CARDINAL': 3},
#   '三十一歲': {'DATE': 1},
#   '三千年前': {'DATE': 1},
#   '三百多年': {'DATE': 1},
#   '上海': {'GPE': 1},
#   '中世紀': {'DATE': 1},
#   '中共': {'ORG': 1},
#   '中勖赫魯曉夫': {'PERSON': 1},
#   '中午': {'TIME': 2},
#   '中國': {'GPE': 3},
#   '中國人': {'NORP': 5},
#   '中國地方自治函授學校': {'ORG': 1},
#   '中央黨校': {'ORG': 1},
#   '中東': {'LOC': 8},
#   '中颐地方自治學會': {'ORG': 1},
#   '之一': {'CARDINAL': 2},
#   '九': {'CARDINAL': 1},
#   '九龍灤水埗醫局街嘉寶大茶樓地廳': {'FAC': 1},
#   '二': {'CARDINAL': 2},
#   '二十': {'CARDINAL': 1},
#   '二十一世紀霍土公司': {'ORG': 1},
#   '二十五年': {'DATE': 1},
#   '二時': {'TIME': 1},
#   '二月九日': {'DATE': 1},
#   '二萬': {'CARDINAL': 1},
#   '五』十分之一': {'CARDINAL': 1},
#   '五十': {'CARDINAL': 1},
#   '五十年': {'DATE': 1},
#   '五十週年': {'DATE': 1},
#   '五年': {'DATE': 1},
#   '人民公社': {'ORG': 1},
#   '今天': {'DATE': 3},
#   '今年': {'DATE': 1},
#   '他文如': {'PERSON': 1},
#   '以色列': {'GPE': 7},
#   '何勳和': {'PERSON': 1},
#   '俄': {'GPE': 1},
#   '俄共': {'ORG': 1},
#   '倫敦': {'GPE': 1},
#   '元月四日下午七瞎卅分': {'TIME': 1},
#   '兩': {'CARDINAL': 3},
#   '兩年之後': {'DATE': 1},
#   '兩年後': {'DATE': 1},
#   '八十': {'CARDINAL': 1},
#   '八四十': {'DATE': 1},
#   '八屆擠大十二中全會': {'EVENT': 1},
#   '八月': {'DATE': 1},
#   '八縛擴大十二中金會': {'ORG': 1},
#   '六十': {'CARDINAL': 1},
#   '六十號': {'DATE': 1},
#   '共黨': {'ORG': 2},
#   '函授學校': {'ORG': 1},
#   '劉': {'PERSON': 2},
#   '劉少奇': {'PERSON': 10},
#   '劉當': {'PERSON': 1},
#   '劉道平': {'PERSON': 1},
#   '劉餽': {'PERSON': 1},
#   '北平': {'GPE': 2},
#   '北越': {'GPE': 1},
#   '匿史': {'PERSON': 1},
#   '十': {'CARDINAL': 1},
#   '十1月十日': {'DATE': 1},
#   '十一': {'CARDINAL': 1},
#   '十一時': {'TIME': 1},
#   '十六日上午': {'TIME': 1},
#   '十四日': {'DATE': 1},
#   '十字軍': {'ORG': 1},
#   '十虢': {'CARDINAL': 1},
#   '卅八年十月': {'DATE': 1},
#   '南京': {'GPE': 1},
#   '南昌': {'GPE': 1},
#   '南越': {'GPE': 1},
#   '去年聖誕前後': {'DATE': 1},
#   '反共': {'ORG': 2},
#   '古√地治': {'PERSON': 1},
#   '台北': {'GPE': 1},
#   '台北中山堂光復廳': {'FAC': 1},
#   '台北區區吩建設委員會': {'ORG': 1},
#   '台北市': {'GPE': 1},
#   '台灣': {'GPE': 2},
#   '史魔': {'PERSON': 1},
#   '和平日': {'DATE': 1},
#   '哈佛大學': {'ORG': 1},
#   '唐淵琛': {'PERSON': 1},
#   '四': {'CARDINAL': 1},
#   '四五千年': {'DATE': 1},
#   '四十五秒鐘': {'TIME': 1},
#   '四十年': {'DATE': 1},
#   '四肢': {'CARDINAL': 1},
#   '圃府': {'ORG': 2},
#   '國民大會': {'ORG': 1},
#   '地中海': {'LOC': 1},
#   '埃及': {'GPE': 1},
#   '埃及人': {'NORP': 1},
#   '基辛加': {'PERSON': 1},
#   '大陸': {'GPE': 1},
#   '天主教': {'ORG': 2},
#   '天文台': {'ORG': 1},
#   '太平洋鼓吹集': {'ORG': 1},
#   '姬露絲': {'PERSON': 2},
#   '婆羅洲': {'LOC': 1},
#   '宋元鴉': {'PERSON': 1},
#   '容里': {'GPE': 1},
#   '尼克遜': {'PERSON': 2},
#   '川': {'GPE': 1},
#   '巴里夫': {'PERSON': 1},
#   '巴黎': {'GPE': 1},
#   '布列茲涅夫': {'PERSON': 1},
#   '彭': {'PERSON': 1},
#   '律賓': {'GPE': 1},
#   '律賓人': {'NORP': 1},
#   '意大利': {'GPE': 1},
#   '捷克': {'GPE': 2},
#   '數十年': {'DATE': 1},
#   '文化革命': {'EVENT': 1},
#   '新台幣壹拾元一一': {'MONEY': 1},
#   '於民圃': {'PERSON': 1},
#   '旅港': {'GPE': 2},
#   '早晨': {'TIME': 1},
#   '明天': {'DATE': 1},
#   '昨天': {'DATE': 1},
#   '時装世界': {'WORK_OF_ART': 1},
#   '時裝世界': {'WORK_OF_ART': 1},
#   '普爾': {'PERSON': 4},
#   '望湛亭': {'FAC': 1},
#   '朝': {'GPE': 1},
#   '本年': {'DATE': 1},
#   '本港訊': {'PERSON': 1},
#   '李公榮壽': {'PERSON': 1},
#   '李宗': {'PERSON': 1},
#   '李宗黄': {'PERSON': 2},
#   '李林李章章': {'PERSON': 1},
#   '李玉豐': {'PERSON': 1},
#   '李萜強': {'PERSON': 1},
#   '東北': {'LOC': 1},
#   '東北宋': {'LOC': 1},
#   '東南': {'LOC': 1},
#   '東南亞': {'LOC': 2},
#   '東麻年': {'DATE': 1},
#   '林彪': {'PERSON': 1},
#   '柯錫金': {'PERSON': 1},
#   '梯田': {'WORK_OF_ART': 1},
#   '武濠': {'GPE': 1},
#   '毛': {'PERSON': 5},
#   '毛儈邁': {'PERSON': 1},
#   '毛共': {'ORG': 1},
#   '毛共前組織部': {'ORG': 1},
#   '毛奮': {'PERSON': 1},
#   '毛旨心': {'PERSON': 1},
#   '毛林': {'ORG': 1},
#   '毛林派': {'ORG': 3},
#   '毛派': {'ORG': 1},
#   '毛澤東': {'PERSON': 4},
#   '毛澤東羅織': {'ORG': 1},
#   '毛酋': {'GPE': 1, 'PERSON': 4},
#   '毫壹幣港伦': {'MONEY': 1},
#   '法國': {'NORP': 1},
#   '泰寗': {'PERSON': 1},
#   '港': {'GPE': 2},
#   '港幣五元': {'MONEY': 1},
#   '滴铡': {'PERSON': 1},
#   '瀚亿麗': {'PERSON': 1},
#   '王世昭': {'PERSON': 1},
#   '王恩茂': {'PERSON': 1},
#   '當晚': {'TIME': 1},
#   '白天': {'TIME': 1},
#   '百敏十條': {'LAW': 1},
#   '百萬': {'CARDINAL': 1},
#   '皚頓道': {'FAC': 1},
#   '碧嬌': {'PERSON': 1},
#   '碧崎': {'GPE': 1},
#   '碧崎市': {'GPE': 1},
#   '福建': {'GPE': 1},
#   '秦': {'GPE': 1},
#   '第一': {'ORDINAL': 2},
#   '第四': {'ORDINAL': 1},
#   '第（': {'ORDINAL': 1},
#   '簧炳鈞': {'PERSON': 1},
#   '籰寅': {'PERSON': 1},
#   '約旦': {'GPE': 1},
#   '納鰱': {'PERSON': 1},
#   '紐約': {'GPE': 1},
#   '總統府': {'ORG': 1},
#   '缀基曼蚕': {'PERSON': 1},
#   '羅瑞娜': {'PERSON': 1},
#   '美': {'GPE': 3},
#   '美國': {'GPE': 4, 'NORP': 1},
#   '美國人': {'NORP': 1},
#   '美洲': {'LOC': 1},
#   '聖誕後一日': {'DATE': 1},
#   '聯合政府': {'ORG': 1},
#   '肖': {'PERSON': 1},
#   '胡辛': {'PERSON': 1},
#   '英國': {'GPE': 1},
#   '英語': {'LANGUAGE': 1},
#   '莫斯科': {'GPE': 1},
#   '菲律賓': {'GPE': 2},
#   '菲律賓人': {'NORP': 1},
#   '菲律賓曆史學會': {'ORG': 1},
#   '萤文琦': {'PERSON': 1},
#   '董文琦': {'PERSON': 1},
#   '蓮': {'PERSON': 1},
#   '蕾金山': {'GPE': 1},
#   '蘇俄': {'GPE': 1},
#   '蘇修走狗': {'PERSON': 1},
#   '蘇聯': {'GPE': 2},
#   '血穌': {'PERSON': 1},
#   '西北': {'LOC': 3},
#   '西洋': {'LOC': 1},
#   '西班矛': {'GPE': 1},
#   '詹森': {'PERSON': 1},
#   '貴劉疊舰': {'PERSON': 1},
#   '赤色王朝': {'DATE': 1},
#   '越': {'GPE': 1},
#   '越南': {'GPE': 6},
#   '越南人': {'NORP': 1},
#   '越南共和國': {'GPE': 1},
#   '輿國府': {'ORG': 1},
#   '那晚': {'TIME': 1},
#   '邱仕': {'PERSON': 1},
#   '郭沫若': {'PERSON': 1},
#   '鄹少奇': {'PERSON': 1},
#   '酱爾': {'PERSON': 1},
#   '醱韶': {'PERSON': 1},
#   '長安東路': {'LOC': 1},
#   '阿刺伯': {'NORP': 5, 'PERSON': 1},
#   '阿刺伯集團': {'ORG': 1},
#   '阿拉伯': {'NORP': 1},
#   '陳伯達': {'PERSON': 1},
#   '陳孝咸': {'PERSON': 1},
#   '陳孝威': {'PERSON': 1},
#   '陳誠': {'PERSON': 1},
#   '陳陸': {'PERSON': 1},
#   '隋唐': {'DATE': 1},
#   '雷時柬推': {'PERSON': 1},
#   '非洲': {'LOC': 1},
#   '饿共': {'ORG': 1},
#   '香墦': {'GPE': 1},
#   '香港': {'GPE': 5},
#   '香港天文台報社': {'ORG': 1},
#   '香港禮頓': {'GPE': 1},
#   '馬尼': {'GPE': 1},
#   '魏偷有': {'PERSON': 1},
#   '鶯齡': {'PERSON': 1},
#   '黃壽': {'PERSON': 1},
#   '黃帝': {'PERSON': 1},
#   '黃帝氏': {'PERSON': 1},
#   '黃炳鈞': {'PERSON': 1},
#   '黎巴嫩': {'GPE': 2},
#   '．L·海雪': {'PERSON': 1}}}
